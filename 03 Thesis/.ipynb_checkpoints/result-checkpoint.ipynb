# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection  import train_test_split
from sklearn.linear_model  import LogisticRegression
from sklearn.preprocessing  import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import statsmodels.api as sm
import seaborn as sns

# %%
df_p = pd.read_csv('Q_50+B.csv')

# %%
df_res = df_p[['Arecord','Urecord','Arate','Pyrate','Arecord_BF','Urecord_BF','Accepted']]
correlation_mat = df_res.astype('float').corr()
sns.heatmap(correlation_mat,annot = True)
plt.show()

# %%
#x=df_p[['Arecord','Urecord','Arate']].values.tolist()
x=df_p[['Arate','Pyrate']].values.tolist()
y=df_p[['Accepted']].values.tolist()

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=120)

# %%
sc=StandardScaler()

sc.fit(x_train)

x_train_nor=sc.transform(x_train)
x_test_nor=sc.transform(x_test)

# %%
lr=LogisticRegression()
lr.fit(x_train_nor,y_train)

print(lr.coef_)
print(lr.intercept_ )
# Out:
# [[-0.21809637  2.62704727 -0.02932898]]
# [-0.21825956]
# /Users/wuyunwei/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_test_pred = lr.predict(x_test_nor)

# %%
lr.score(x_test,y_test)
# Out:
# 0.8249979486337901

# %%
x_train_nor = sm.add_constant(x_train_nor)

log_reg = sm.Logit(y_train, x_train_nor).fit()
print(log_reg.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.689289
#          Iterations 3
#                           Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.000
# Dependent Variable: y                AIC:              156809.7043
# Date:               2021-11-17 20:58 BIC:              156838.6294
# No. Observations:   113743           Log-Likelihood:   -78402.
# Df Model:           2                LL-Null:          -78403.
# Df Residuals:       113740           LLR p-value:      0.36468
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     3.0000
# --------------------------------------------------------------------
#            Coef.    Std.Err.      z       P>|z|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.1758     0.0060   -29.5330   0.0000   -0.1875   -0.1641
# x1         0.0072     0.0060     1.2118   0.2256   -0.0045    0.0189
# ...

# %%
x=df_p[['Arate']].values.tolist()
y=df_p[['Accepted']].values.tolist()

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100) 

lr=LogisticRegression()
lr.fit(x_train,y_train)

print(lr.coef_)
print(lr.intercept_ )

y_pred = lr.predict(x_test)
print('accuracy =',accuracy_score(y_test, y_pred))
print('recall =',recall_score(y_test, y_pred))
print('precision =',precision_score(y_test, y_pred, zero_division=0))
print('f1 score =',f1_score(y_test, y_pred))

plot_confusion_matrix(lr, x_test, y_test)  
plt.show()
# Out:
# /Users/wuyunwei/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [[6.8833693]]
# [-3.71820798]
# accuracy = 0.8249979486337901
# recall = 0.7926470588235294
# precision = 0.8210016155088853
# f1 score = 0.8065752182292256

# %%
x_train = sm.add_constant(x_train)

log_reg = sm.Logit(y_train, x_train).fit()
print(log_reg.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.334051
#          Iterations 7
#                          Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.515
# Dependent Variable: y                AIC:              75995.9155
# Date:               2021-11-17 20:58 BIC:              76015.1989
# No. Observations:   113743           Log-Likelihood:   -37996.
# Df Model:           1                LL-Null:          -78403.
# Df Residuals:       113741           LLR p-value:      0.0000
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     7.0000
# -------------------------------------------------------------------
#          Coef.    Std.Err.       z       P>|z|     [0.025    0.975]
# -------------------------------------------------------------------
# const   -3.7238     0.0230   -162.1219   0.0000   -3.7688   -3.6788
# x1       6.8936     0.0387    178.2633   0.0000    6.8178    6.9694
# ...

# %%
x=df_p[['Pyrate']].values.tolist()
y=df_p[['Accepted']].values.tolist()

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=120) 

lr=LogisticRegression()
lr.fit(x_train,y_train)

print(lr.coef_)
print(lr.intercept_ )
print(lr.score(x_test,y_test))
# Out:
# [[-0.35224809]]
# [0.1140333]
# 0.5418068433576763
# /Users/wuyunwei/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
x_train = sm.add_constant(x_train)

log_reg = sm.Logit(y_train, x_train).fit()
print(log_reg.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.688444
#          Iterations 4
#                           Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.002
# Dependent Variable: y                AIC:              156615.3399
# Date:               2021-11-17 19:41 BIC:              156634.6233
# No. Observations:   113743           Log-Likelihood:   -78306.
# Df Model:           1                LL-Null:          -78441.
# Df Residuals:       113741           LLR p-value:      5.7125e-61
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     4.0000
# --------------------------------------------------------------------
#            Coef.    Std.Err.      z       P>|z|     [0.025    0.975]
# --------------------------------------------------------------------
# const      0.1142     0.0181     6.3009   0.0000    0.0787    0.1497
# x1        -0.3524     0.0214   -16.4698   0.0000   -0.3943   -0.3105
# ...

# %%
Xtrain = df_p[['Arecord','Urecord','Arate']]
ytrain = df_p[['Accepted']]

log_reg = sm.Logit(ytrain.astype(float), Xtrain.astype(float)).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.569263
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:               Accepted   No. Observations:               162491
# Model:                          Logit   Df Residuals:                   162488
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 17 Nov 2021   Pseudo R-squ.:                  0.1744
# Time:                        16:59:33   Log-Likelihood:                -92500.
# converged:                       True   LL-Null:                   -1.1204e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Arecord        0.0611      0.001     61.940      0.000       0.059       0.063
# ...

# %%
Xtrain = df_p[['Arecord','Urecord','Arate']]
ytrain = df_p[['Accepted']]

Xtrain = sm.add_constant(Xtrain)

log_reg = sm.Logit(ytrain.astype(float), Xtrain.astype(float)).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.333240
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:               Accepted   No. Observations:               162491
# Model:                          Logit   Df Residuals:                   162487
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Nov 2021   Pseudo R-squ.:                  0.5167
# Time:                        16:59:03   Log-Likelihood:                -54148.
# converged:                       True   LL-Null:                   -1.1204e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.8750      0.021   -183.023      0.000      -3.916      -3.833
# ...
